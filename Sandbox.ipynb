# %%
from trader import Trader

import nest_asyncio
nest_asyncio.apply()
# Out:
# 17:03:00 | DEBUG | EMAIL_USER = john.eicher89@gmail.com
# 17:03:00 | DEBUG | EMAIL_TO = john.eicher89@gmail.com
# /home/saltchicken/workspace/trader/.venv/lib/python3.11/site-packages/backtesting/_plotting.py:55: UserWarning: Jupyter Notebook detected. Setting Bokeh output to notebook. This may not work in Jupyter clients without JavaScript support, such as old IDEs. Reset with `backtesting.set_bokeh_output(notebook=False)`.
#   warnings.warn('Jupyter Notebook detected. '
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ea02d48d-ab74-4426-b60c-404da9844afa">Loading BokehJS ...</span>
#     </div>

# %%
trader = Trader()

# %%
# trader.alpaca.cancel_all_open_orders()

# %%
for order in trader.alpaca.orders:
    print(order.symbol, order.qty, order.side, order.status, order.type)
# Out:
# EGY None OrderSide.BUY OrderStatus.ACCEPTED OrderType.MARKET

# %%
# trader.alpaca.order_buy_market_bracket("AAPL", 100, 150, 140)

# %%
trader.db.get_all_symbols()
# Out:
# ['AYTU',
#  'HRMY',
#  'ACXP',
#  'TPVG',
#  'GSHR',
#  'NMAX',
#  'LAC',
#  'EGHA',
#  'CULP',
#  'CMG',
#  'ALLO',
#  'FSUN',
#  'SCVL',
#  'MGM',
#  'FITB',
#  'ATO',
#  'BOWN',
#  'IMPP',
#  'FIP',
#  'SHC',
#  'MTW',
#  'WKHS',
#  'ZVIA',
#  'SIMA',
#  'CLMB',
#  'CIVB',
#  'NTWO',
#  'SBUX',
#  'COSM',
#  'GDDY',
#  'HPE',
#  'TDY',
#  'UNM',
#  'CBZ',
#  'NOA',
#  'XYL',
#  'TXNM',
#  'MD',
#  'IINN',
#  'WSFS',
#  'ONCO',
#  'AROC',
#  'COOT',
#  'SEG',
#  'COLL',
#  'DCOM',
#  'CARS',
#  'ESHA',
#  'GCTK',
#  'RACE',
#  'PEBK',
#  'HFBL',
#  'BHLB',
#  'PAVM',
#  'DPZ',
#  'STHO',
#  'RAPT',
#  'BDX',
#  'CNP',
#  'SUPN',
#  'FMC',
#  'RMTI',
#  'BTE',
#  'MTEN',
#  'AVGO',
#  'WOLF',
#  'EXFY',
#  'IBKR',
#  'RSSS',
#  'PHH',
#  'CEP',
#  'LGCL',
#  'GPOR',
#  'ADEA',
#  'DJCO',
#  'FATBB',
#  'LUV',
#  'JOBY',
#  'COUR',
#  'MSS',
#  'LEN.B',
#  'APAM',
#  'K',
#  'INM',
#  'PNTG',
#  'WTTR',
#  'HQY',
#  'CBAN',
#  'EEIQ',
#  'MUX',
#  'CPBI',
#  'RXO',
#  'CIFR',
#  'URGN',
#  'PAGS',
#  'MFIC',
#  'OFIX',
#  'DCTH',
#  'BOF',
#  'BSVN',
#  'CHDN',
#  'WEX',
#  'QIPT',
#  'VTOL',
#  'ZBAI',
#  'TELA',
#  'ITIC',
#  'LNW',
#  'ROIV',
#  'APLD',
#  'ISPC',
#  'LINC',
#  'EHTH',
#  'DARE',
#  'RNAZ',
#  'RCEL',
#  'INTC',
#  'BROS',
#  'SPRY',
#  'RELY',
#  'SNTI',
#  'EVH',
#  'IPAR',
#  'NBR',
#  'CRWS',
#  'MYPS',
#  'HBIO',
#  'CHCI',
#  'NCI',
#  'FLXS',
#  'MTVA',
#  'UIS',
#  'EL',
#  'METCB',
#  'NVNI',
#  'TSE',
#  'CHGG',
#  'AMRK',
#  'SWBI',
#  'COR',
#  'VAC',
#  'EHGO',
#  'VLGEA',
#  'NABL',
#  'AGI',
#  'FELE',
#  'NET',
#  'USEA',
#  'BANC',
#  'CSTE',
#  'TEM',
#  'AAUC',
#  'EXTR',
#  'PI',
#  'DBRG',
#  'MRX',
#  'JCI',
#  'PCB',
#  'ZIM',
#  'LRN',
#  'GFR',
#  'FMAO',
#  'PRSO',
#  'USB',
#  'CSTM',
#  'FLO',
#  'NBHC',
#  'ITT',
#  'PMTS',
#  'CNSP',
#  'OMF',
#  'HL',
#  'QSI',
#  'AU',
#  'SAM',
#  'DGLY',
#  'DRMA',
#  'CENN',
#  'FCBC',
#  'NIC',
#  'BAC',
#  'HLLY',
#  'THRM',
#  'BCBP',
#  'OOMA',
#  'BRO',
#  'NFG',
#  'SDM',
#  'BIOX',
#  'BLNK',
#  'BSY',
#  'SONO',
#  'IRDM',
#  'SMPL',
#  'FOXX',
#  'KALA',
#  'MATH',
#  'MSTR',
#  'TMUS',
#  'GD',
#  'QTTB',
#  'CYCU',
#  'BWLP',
#  'CVRX',
#  'CPA',
#  'WSBF',
#  'BCRX',
#  'ADN',
#  'CHWY',
#  'TKR',
#  'TTWO',
#  'PMN',
#  'SLB',
#  'LPRO',
#  'NCEW',
#  'ITRN',
#  'MCO',
#  'GNE',
#  'BY',
#  'LNN',
#  'GNPX',
#  'STE',
#  'DHR',
#  'PVBC',
#  'BKE',
#  'AMC',
#  'ANVS',
#  'BACQ',
#  'AMST',
#  'NEXT',
#  'FRO',
#  'DVN',
#  'QNTM',
#  'IVVD',
#  'NAKA',
#  'RIBB',
#  'CRCT',
#  'SDHI',
#  'KVUE',
#  'AWR',
#  'NGVT',
#  'VKTX',
#  'CGNT',
#  'CPHC',
#  'ICL',
#  'MOV',
#  'RMAX',
#  'AEO',
#  'FERG',
#  'SWX',
#  'RAND',
#  'ONON',
#  'SEE',
#  'MAXN',
#  'OTIS',
#  'GMED',
#  'MATV',
#  'INTU',
#  'FRAF',
#  'MLAC',
#  'ZS',
#  'PKBK',
#  'SMSI',
#  'NHTC',
#  'MNDR',
#  'IMXI',
#  'ZDAI',
#  'AXON',
#  'STGW',
#  'HURA',
#  'BRSL',
#  'MMYT',
#  'CDLX',
#  'AAM',
#  'ZKIN',
#  'MYNZ',
#  'EQS',
#  'KRO',
#  'ERNA',
#  'COPL',
#  'PYXS',
#  'MAAS',
#  'AOSL',
#  'ZION',
#  'TRML',
#  'RVSN',
#  'XYZ',
#  'ACIC',
#  'KAI',
#  'CHTR',
#  'PKE',
#  'HEI',
#  'NDSN',
#  'TMCI',
#  'SAH',
#  'ADTX',
#  'CFLT',
#  'PWP',
#  'PPC',
#  'BIIB',
#  'FL',
#  'LPAA',
#  'EYE',
#  'HCTI',
#  'SGC',
#  'THC',
#  'EGBN',
#  'MIGI',
#  'DKS',
#  'WTF',
#  'COMP',
#  'OMER',
#  'BIYA',
#  'MVIS',
#  'CLBR',
#  'HLMN',
#  'ABCL',
#  'APOG',
#  'WAFD',
#  'RAY',
#  'SBLK',
#  'BMEA',
#  'EPC',
#  'ASTC',
#  'CHEK',
#  'POET',
#  'RY',
#  'VMEO',
#  'ERII',
#  'ECPG',
#  'MRC',
#  'IRON',
#  'RELL',
#  'DXPE',
#  'ACB',
#  'AVO',
#  'CETY',
#  'CODX',
#  'XPER',
#  'ASTS',
#  'REAX',
#  'VTS',
#  'MSEX',
#  'OZK',
#  'ONDS',
#  'GLUE',
#  'AGL',
#  'ZJK',
#  'ATNF',
#  'PRGS',
#  'NINE',
#  'BDMD',
#  'PBYI',
#  'MFI',
#  'VSTS',
#  'BTOC',
#  'MDXH',
#  'TRC',
#  'USCB',
#  'CRGO',
#  'JXN',
#  'IZEA',
#  'WSC',
#  'SRM',
#  'SURG',
#  'FTV',
#  'VIRC',
#  'CRMD',
#  'PRAX',
#  'CPIX',
#  'CEPO',
#  'CNXN',
#  'SSSS',
#  'LDOS',
#  'LMT',
#  'ATEN',
#  'CSX',
#  'ATXG',
#  'ZYME',
#  'FVCB',
#  'RDVT',
#  'ASO',
#  'BTM',
#  'SMBC',
#  'IMVT',
#  'ASPS',
#  'ALZN',
#  'ACHC',
#  'ZM',
#  'SWVL',
#  'NMRA',
#  'TRUP',
#  'MRVI',
#  'MDXG',
#  'SATL',
#  'WOR',
#  'ALRM',
#  'BFH',
#  'MNMD',
#  'TGLS',
#  'UCAR',
#  'CDE',
#  'TWLO',
#  'SATS',
#  'JBLU',
#  'FLGT',
#  'ZETA',
#  'CWCO',
#  'USGO',
#  'DTST',
#  'AVA',
#  'INDP',
#  'DBX',
#  'LVLU',
#  'QTRX',
#  'MHUA',
#  'GCMG',
#  'GIGM',
#  'ABBV',
#  'IMMR',
#  'CECO',
#  'LTH',
#  'ORGO',
#  'SMLR',
#  'BMY',
#  'PRG',
#  'GEV',
#  'PLL',
#  'MCTR',
#  'EFXT',
#  'PATK',
#  'SABS',
#  'UTSI',
#  'CELH',
#  'ADTN',
#  'HUHU',
#  'GPK',
#  'CELC',
#  'MIRA',
#  'BAFN',
#  'NVNO',
#  'MANH',
#  'PLBC',
#  'BOW',
#  'BOTJ',
#  'RNG',
#  'ALVO',
#  'CTSH',
#  'HIVE',
#  'KIDS',
#  'SYBX',
#  'VS',
#  'MB',
#  'PX',
#  'PTON',
#  'QMMM',
#  'POAI',
#  'IRBT',
#  'ALT',
#  'JBSS',
#  'NYT',
#  'KINS',
#  'NCNO',
#  'MDCX',
#  'TRS',
#  'SES',
#  'EXC',
#  'AM',
#  'KLTO',
#  'CHR',
#  'F',
#  'PFS',
#  'MAPS',
#  'DAY',
#  'VTSI',
#  'VIGL',
#  'TPB',
#  'CPRI',
#  'ZURA',
#  'IVP',
#  'ALGM',
#  'WOOF',
#  'RAYA',
#  'OCC',
#  'MNY',
#  'FFIC',
#  'MNTS',
#  'RBA',
#  'BCAX',
#  'DLPN',
#  'ZIP',
#  'PWOD',
#  'FORM',
#  'TROW',
#  'HRL',
#  'EVTV',
#  'OWLT',
#  'IAC',
#  'UCB',
#  'CUPR',
#  'CVCO',
#  'OPAD',
#  'HVT.A',
#  'CINF',
#  'AMTB',
#  'MNDY',
#  'KZR',
#  'ABLV',
#  'COKE',
#  'RYAM',
#  'ELVN',
#  'VLN',
#  'CCEC',
#  'AIP',
#  'OSRH',
#  'DINO',
#  'RBC',
#  'REYN',
#  'MLKN',
#  'CYCC',
#  'KFS',
#  'ACEL',
#  'HTOO',
#  'HSHP',
#  'BCO',
#  'SMID',
#  'HSY',
#  'RGR',
#  'SKX',
#  'LIVN',
#  'IBIO',
#  'ICON',
#  'CSWC',
#  'KR',
#  'INTZ',
#  'CMPO',
#  'AQMS',
#  'GNSS',
#  'FMFC',
#  'SHFS',
#  'BKV',
#  'NTRA',
#  'OPEN',
#  'NRSN',
#  'ATEC',
#  'PCG',
#  'ARAY',
#  'TEX',
#  'KWM',
#  'CVAC',
#  'LANV',
#  'EURK',
#  'CLFD',
#  'GEF',
#  'SMP',
#  'DVAX',
#  'ICU',
#  'STKL',
#  'ABM',
#  'CRCL',
#  'SPR',
#  'RNTX',
#  'XCUR',
#  'PRQR',
#  'CMCSA',
#  'BGS',
#  'TGT',
#  'PBF',
#  'ADV',
#  'NKTR',
#  'GXAI',
#  'ABCB',
#  'WAFU',
#  'GRBK',
#  'WRBY',
#  'PCT',
#  'NFLX',
#  'JPM',
#  'UPLD',
#  'INVA',
#  'CSBR',
#  'WAY',
#  'HCSG',
#  'SLDE',
#  'OTRK',
#  'DOW',
#  'CETX',
#  'SMMT',
#  'SSBI',
#  'LUMN',
#  'HITI',
#  'ALUR',
#  'LDWY',
#  'ARCB',
#  'VUZI',
#  'META',
#  'SSTK',
#  'SEM',
#  'GHLD',
#  'NXXT',
#  'BH',
#  'CWK',
#  'LIMN',
#  'LAW',
#  'HKPD',
#  'COFS',
#  'BTCT',
#  'CNTY',
#  'VVOS',
#  'ANIP',
#  'SWKS',
#  'QSR',
#  'LPTH',
#  'CARE',
#  'DUK',
#  'CAT',
#  'LQDT',
#  'FEBO',
#  'OPY',
#  'ETR',
#  'EMBC',
#  'LGO',
#  'ORIC',
#  'KMTS',
#  'INGR',
#  'AES',
#  'MO',
#  'FIS',
#  'ANNX',
#  'XELB',
#  'AMCX',
#  'SNGX',
#  'NDAQ',
#  'ACRV',
#  'QUAD',
#  'SRTS',
#  'CWST',
#  'AR',
#  'CON',
#  'TOL',
#  'KLXE',
#  'SLS',
#  'FORD',
#  'CP',
#  'ACMR',
#  'AIHS',
#  'INVZ',
#  'ECDA',
#  'ALG',
#  'VEEA',
#  'SPB',
#  'HWM',
#  'HTCR',
#  'TTI',
#  'LVTX',
#  'NXT',
#  'DORM',
#  'ENVA',
#  'SHIP',
#  'BL',
#  'AJG',
#  'SOUN',
#  'LBTYA',
#  'ALLT',
#  'JZXN',
#  'YETI',
#  'JBL',
#  'AMPL',
#  'QTWO',
#  'UPBD',
#  'TMHC',
#  'NSPR',
#  'PKG',
#  'ANGH',
#  'UPWK',
#  'HVT',
#  'RPM',
#  'UNB',
#  'RAIN',
#  'MASS',
#  'ICCC',
#  'PKOH',
#  'KNDI',
#  'PRAA',
#  'PDLB',
#  'BHST',
#  'HLIT',
#  'PETZ',
#  'CURR',
#  'XLO',
#  'STLA',
#  'FG',
#  'RR',
#  'NWS',
#  'GOSS',
#  'RCKY',
#  'TAIT',
#  'SBGI',
#  'ALNT',
#  'SKIN',
#  'HAYW',
#  'APM',
#  'ONMD',
#  'PHM',
#  'CIA',
#  'LNC',
#  'PVLA',
#  'RNR',
#  'RGCO',
#  'OCTO',
#  'LB',
#  'LMB',
#  'BSGM',
#  'ORCL',
#  'YTRA',
#  'FSLY',
#  'BPRN',
#  'MODD',
#  'MCY',
#  'DMAA',
#  'UGI',
#  'GSIT',
#  'LKQ',
#  'TBN',
#  'MCHP',
#  'OI',
#  'EDHL',
#  'GBIO',
#  'PLXS',
#  'DLHC',
#  'APEI',
#  'SPOT',
#  'NEOV',
#  'TDG',
#  'FLYE',
#  'PYPD',
#  'WALD',
#  'INV',
#  'FIGS',
#  'YORW',
#  'TSQ',
#  'GYRE',
#  'MNPR',
#  'OPRX',
#  'TALO',
#  'GHC',
#  'FORR',
#  'HON',
#  'KTB',
#  'SA',
#  'VC',
#  'INFA',
#  'ATPC',
#  'HPAI',
#  'WFRD',
#  'RGLD',
#  'AFG',
#  'LITM',
#  'TOYO',
#  'BRTX',
#  'APRE',
#  'PMCB',
#  'SHBI',
#  'STRZ',
#  'FUL',
#  'THS',
#  'NXGL',
#  'TNMG',
#  'WMB',
#  'ODV',
#  'ATYR',
#  'ELSE',
#  'TCBK',
#  'MRNO',
#  'NWBI',
#  'SCS',
#  'SITE',
#  'CCS',
#  'GWH',
#  'UONEK',
#  'ADIL',
#  'WAI',
#  'PCOR',
#  'MGYR',
#  'TVRD',
#  'OSUR',
#  'BCC',
#  'GHRS',
#  'TENX',
#  'KSS',
#  'INBK',
#  'ESLT',
#  'EPIX',
#  'COLA',
#  'CGON',
#  'JBDI',
#  'AMD',
#  'ANDE',
#  'UBER',
#  'MPB',
#  'EZPW',
#  'BBSI',
#  'MTD',
#  'SEMR',
#  'DHIL',
#  'WYNN',
#  'R',
#  'IDYA',
#  'KFY',
#  'GIFT',
#  'DFH',
#  'APG',
#  'SBFG',
#  'ENS',
#  'HOND',
#  'DFLI',
#  'RSKD',
#  'ZYBT',
#  'NAVI',
#  'UFI',
#  'PSIG',
#  'GETY',
#  'AIFE',
#  'OSW',
#  'CHSN',
#  'VTVT',
#  'CVLT',
#  'FBP',
#  'GIII',
#  'OBK',
#  'FDS',
#  'UDMY',
#  'MA',
#  'DENN',
#  'HALO',
#  'BEN',
#  'AMG',
#  'CAE',
#  'REGN',
#  'HNGE',
#  'ALTI',
#  'GABC',
#  'TTAM',
#  'CWAN',
#  'CASS',
#  'RCMT',
#  'OPRT',
#  'OKE',
#  'HAIN',
#  'NRDY',
#  'INO',
#  'MGNI',
#  'SITM',
#  'PAHC',
#  'STRR',
#  'MBRX',
#  'BGC',
#  'MSA',
#  'HFWA',
#  'ESEA',
#  'TOWN',
#  'DTSQ',
#  'CEG',
#  'EA',
#  'YHGJ',
#  'DNOW',
#  'MTAL',
#  'AAMI',
#  'BOXL',
#  'THG',
#  'PLOW',
#  'BGLC',
#  'INBX',
#  'BTSG',
#  'ACI',
#  'MSI',
#  'PHIN',
#  'CASK',
#  'MBC',
#  'SBCF',
#  'FENC',
#  'TTSH',
#  'SOPA',
#  'ARTNA',
#  'FBIO',
#  'BN',
#  'APVO',
#  'MASI',
#  'ACET',
#  'APD',
#  'HURN',
#  'BALY',
#  'FROG',
#  'AIRT',
#  'MFH',
#  'DVLT',
#  'ESAB',
#  'PSEC',
#  'TSSI',
#  'BIO',
#  'WLY',
#  'ZTS',
#  'DAVE',
#  'GTLS',
#  'GFL',
#  'CSPI',
#  'UVV',
#  'HLI',
#  'ISPR',
#  'MHO',
#  'GMGI',
#  'IRD',
#  'PGY',
#  'NBBK',
#  'ONEG',
#  'GEHC',
#  'CRBP',
#  'HLP',
#  'RELI',
#  'CING',
#  'RKDA',
#  'BKNG',
#  'BIVI',
#  'TMDX',
#  'CREV',
#  'WXM',
#  'KNTK',
#  'NXPL',
#  'AGX',
#  'VSEE',
#  'BATRA',
#  'OSCR',
#  'AMAT',
#  'JYNT',
#  'GMHS',
#  'CERO',
#  'HASI',
#  'SPFI',
#  'OLN',
#  'DTIL',
#  'GPRO',
#  'HYFM',
#  'MTSI',
#  'CXW',
#  'PTHL',
#  'LH',
#  'KPLT',
#  'HOFT',
#  'HVII',
#  'DXR',
#  'TARS',
#  'HCI',
#  'FSTR',
#  'LXEO',
#  'MPC',
#  'ADSE',
#  'MKDW',
#  'CLPT',
#  'SAIH',
#  'AEBI',
#  'ORKA',
#  'AVT',
#  'SMCI',
#  'IGIC',
#  'EME',
#  'LASR',
#  'PC',
#  'VCIC',
#  'DTM',
#  'SBXD',
#  'NCRA',
#  'TCBS',
#  'MCFT',
#  'TSAT',
#  'WBTN',
#  'FTFT',
#  'HLT',
#  'GYRO',
#  'SPKL',
#  'RBKB',
#  'AEMD',
#  'CYRX',
#  'ASC',
#  'OBLG',
#  'DAR',
#  'ST',
#  'WLDS',
#  'BXSL',
#  'MBX',
#  'CDRO',
#  'SOUL',
#  'VRDN',
#  'UNH',
#  'FBLG',
#  'BKYI',
#  'VACH',
#  'VRA',
#  'CVGI',
#  'ADSK',
#  'ABEO',
#  ...]

# %%
trader.calculate_and_update_scores("META")
# Out:
# High: 747.9, Low: 442.65
# Week 52 Score: -0.8499590499590501
# 📥 Downloading data for ['META'] from Alpaca in single API call...
# ✅ Downloaded 499 rows of data for META
# Cross Score: 0.0
# Composite Score: -0.3902692571929771
